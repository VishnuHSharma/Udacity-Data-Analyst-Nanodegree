# %% [markdown]
# ## Investigating a movie dataset obtained from Kaggle(IMDB movie data. This project is a part of Udacity's Data Analyst Nanodegree program. Being a film fan, I chose to analyze this dataset which contains information about movies.
#
# ## We will be utilizing Python's data analysis stack in order to import and analyze and ultimately derive interesting insights from this dataset.

# %% [markdown]
# #### Importing the relevant libraries and initial analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
movies = pd.read_csv('tmdb-movies.csv')

movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
movies.describe(include='all')
# Out:
#                    id    imdb_id    popularity        budget       revenue  \
# count    10866.000000      10856  10866.000000  1.086600e+04  1.086600e+04
# unique            NaN      10855           NaN           NaN           NaN
# top               NaN  tt0411951           NaN           NaN           NaN
# freq              NaN          2           NaN           NaN           NaN
# mean     66064.177434        NaN      0.646441  1.462570e+07  3.982332e+07
# std      92130.136561        NaN      1.000185  3.091321e+07  1.170035e+08
# min          5.000000        NaN      0.000065  0.000000e+00  0.000000e+00
# 25%      10596.250000        NaN      0.207583  0.000000e+00  0.000000e+00
# 50%      20669.000000        NaN      0.383856  0.000000e+00  0.000000e+00
# 75%      75610.000000        NaN      0.713817  1.500000e+07  2.400000e+07
# max     417859.000000        NaN     32.985763  4.250000e+08  2.781506e+09
#
# ...

# %% [markdown]
# #### Based on initial analysis, we can see that there are a total of 10,866 samples in this dataset and 21 features. There are, however, numerous columns in which there are missing values. These majority of the missing values are homepage, tagline, keywords, and production companies. In this project, we are mainly interested in analyzing various quantative features such as budget and revenus and observing various trends over the years. Therfore, we can outright drop these columns. However, if we were interested in developing some sort of recommendation system, we would probably keep the keywords column.

# %%
movies = movies.drop(['homepage', 'tagline', 'keywords', 'production_companies'], axis=1)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              10866 non-null  int64
#  1   imdb_id         10856 non-null  object
#  2   popularity      10866 non-null  float64
#  3   budget          10866 non-null  int64
#  4   revenue         10866 non-null  int64
#  5   original_title  10866 non-null  object
#  6   cast            10790 non-null  object
#  7   director        10822 non-null  object
#  8   overview        10862 non-null  object
#  9   runtime         10866 non-null  int64
#  10  genres          10843 non-null  object
#  11  release_date    10866 non-null  object
#  12  vote_count      10866 non-null  int64
#  13  vote_average    10866 non-null  float64
#  14  release_year    10866 non-null  int64
#  15  budget_adj      10866 non-null  float64
#  16  revenue_adj     10866 non-null  float64
# ...

# %% [markdown]
# #### The columns have been dropped.

# %% [markdown]
# ### Are movie budgets increasing year over year?

# %%
avg_budget_years = movies.groupby('release_year')['budget'].mean()

# %%
def plot_asthetics(title, xlabel, ylabel):
    """  This is a custom function to avoid repeating the lines of code that
         write the titles, the axis of the plots
    """
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
avg_budget_years.plot(figsize=(10, 6))
plot_asthetics('Average Movie Budget(Non-Adjusted)', 'Year', 'Average Budget(Millions)')

# %% [markdown]
# #### As we can interpret from this chart, average movie budget has been increasing since movies first began, which again is understandable. It is also important to note that this dataset does not contain the more recent movies like Avengers. Also there are interesting peaks around the mid 2000s which could coincide with the release of Avatar.

# %% [markdown]
# ### Are movies getting longer?

# %%
average_runtime = movies.groupby('release_year')['runtime'].mean()

# %%
average_runtime.plot(figsize=(10, 6))
plot_asthetics('Average Movie Runtime', 'Year', 'Average Runtime(Minutes)')

# %% [markdown]
# #### Again, this is something that could have been anticipated. Movie runtimes are actually getting shorter since the 1960s where they averaged around 2 hours and now closer to just over 90 minutes. Anectodotally, this makes sense as well.

# %% [markdown]
# #### Average Budget Adjusted plot over time.

# %%
avg_budget_adj = movies.groupby('release_year')['budget_adj'].mean()

# %%
avg_budget_adj.plot(figsize=(10, 6))
plot_asthetics('Average Movie Budget(Adjusted)', 'Year', 'Average Budget(Millions)')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              10866 non-null  int64
#  1   imdb_id         10856 non-null  object
#  2   popularity      10866 non-null  float64
#  3   budget          10866 non-null  int64
#  4   revenue         10866 non-null  int64
#  5   original_title  10866 non-null  object
#  6   cast            10790 non-null  object
#  7   director        10822 non-null  object
#  8   overview        10862 non-null  object
#  9   runtime         10866 non-null  int64
#  10  genres          10843 non-null  object
#  11  release_date    10866 non-null  object
#  12  vote_count      10866 non-null  int64
#  13  vote_average    10866 non-null  float64
#  14  release_year    10866 non-null  int64
#  15  budget_adj      10866 non-null  float64
#  16  revenue_adj     10866 non-null  float64
# ...

# %% [markdown]
# ### Who are some of the most prolific directors working in the industry?

# %%
directors = movies['director'].value_counts().sort_values(ascending=False)

# %%
top_ten = directors.head(10)
directors.head()
# Out:
# Woody Allen         45
# Clint Eastwood      34
# Martin Scorsese     29
# Steven Spielberg    29
# Ridley Scott        23
# Name: director, dtype: int64

# %%
top_ten.plot.barh(figsize=(10, 6))
plot_asthetics('Top Ten Movies Directors by Count', 'Movie Directed Count', 'Director')

# %% [markdown]
# ### As we can see, within the constraints of this particular dataset, Woody Allen, Clint Eastwood, and Steven Spielberg have directed the most number of movies.

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### During this project, we utilized several data wrangling methods such as dropping columns that we did not need as well as aggregating data in order to glean insight. For instance, we uncovered that the adjusted movie budgets have been increasing year over year. We also discovered who the most prolific directors are by aggregating by year and frequency count of movies directed.
#
#
# # Limitations
# ### However, there were also limitations when it comes to the project as well. Analysis could be extended by using techniques like text analytics and regular expressions to find other meaningful insights by analyzing the plot descriptions as well as genres. Also, there are limitations in the sense that this dataset is not current and up to date. Analysis will undoubtedly be limited by the number of techniques that are at one's disposal and therefore, if someone does not know that analysis will be limited as it was in this case. However, those techniques are beyond the scope of this particular project.
